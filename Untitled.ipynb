# %%
from app import runSimulation, TimeNumberPlot, AspectRatioTimePlot, AspectWasteRatioPlot

# %%
TimeNumberPlot('Number of robots & Time relation', 'Number of robots', 'Time (Tick)', 20)

# %%
AspectRatioTimePlot('Test', 'Aspect Ratio', 'Time', 1, 100)

# %%
AspectWasteRatioPlot("AspectRatio & WasteRatio", "AspectRatio", "WasteRatio", 1, 100)
